# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('Data1.csv', index_col=0); #albo change index funkcja jakoś tak
print(df)
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5    theta_6
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908   0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288   1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351   2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518   1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092   1.742433
# ...              ...       ...       ...       ...       ...        ...
# 2019-12-27 -1.520171 -1.128868  1.108275  0.936817  0.948045  11.755980
# 2019-12-28  0.338910 -3.178251  1.484579  1.051123  1.025288  11.397092
# 2019-12-29  0.263781  0.045725 -0.112476  0.823782  0.914111  10.918941
# 2019-12-30 -0.425098 -1.002701 -0.834294  0.850904  0.801977  11.140722
# 2019-12-31  0.848302  3.510521 -0.280626  0.967050  1.091803  11.989975
#
# [1095 rows x 6 columns]

# %%
df.plot()

# %%
df2 = pd.melt(df.reset_index(), id_vars='index', value_vars=['theta_1', 'theta_2', 'theta_3', 'theta_4','theta_5','theta_6'])
print(df2)
# Out:
#            index variable      value
# 0     2017-01-01  theta_1   0.756936
# 1     2017-01-02  theta_1   0.767089
# 2     2017-01-03  theta_1   0.404544
# 3     2017-01-04  theta_1   1.313957
# 4     2017-01-05  theta_1   0.209862
# ...          ...      ...        ...
# 6565  2019-12-27  theta_6  11.755980
# 6566  2019-12-28  theta_6  11.397092
# 6567  2019-12-29  theta_6  10.918941
# 6568  2019-12-30  theta_6  11.140722
# 6569  2019-12-31  theta_6  11.989975
#
# [6570 rows x 3 columns]

# %%
g = sns.FacetGrid(df2, col="variable", sharex=False)
g = g.map(plt.hist, "value")

# %%
s1 = pd.Series(df['theta_1'])
ax = s1.plot.kde()

# %%
s2 = pd.Series(df['theta_2'])
ax = s2.plot.kde()

# %%
s3 = pd.Series(df['theta_3'])
ax = s3.plot.kde()

# %%
s4 = pd.Series(df['theta_4'])
ax = s4.plot.kde()

# %%
s5 = pd.Series(df['theta_5'])
ax = s5.plot.kde()

# %%
s6 = pd.Series(df['theta_6'])
ax = s6.plot.kde()

# %%
df.plot(kind='kde')

# %%
df2018 = df['2018-01-01':'2019-01-01']
df2018.plot()

# %%
s1_2018 = pd.Series(df2018['theta_1'])
ax = s1_2018.plot.kde()

# %%
s2_2018 = pd.Series(df2018['theta_2'])
ax = s2_2018.plot.kde()

# %%
s3_2018 = pd.Series(df2018['theta_3'])
ax = s3_2018.plot.kde()

# %%
s4_2018 = pd.Series(df2018['theta_4'])
ax = s4_2018.plot.kde()
